# %% [markdown]
# ## Import libraries

# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import pmdarima as pm

# %% [markdown]
# ### Import data

# %%
cwd = os.getcwd()
simp_path = 'raw_data/df.csv'
abs_path = os.path.abspath(os.path.join(cwd,'..',simp_path))
df_sarimax = pd.read_csv(abs_path)

# %%
df_sarimax.head()
# Out:
#   ticker      open     close  adj_close       low      high     volume  \
# 0   AAPL  3.745536  3.997768   2.686497  3.631696  4.017857  133949200
# 1   AAPL  3.866071  3.660714   2.459998  3.613839  3.950893  128094400
# 2   AAPL  3.705357  3.714286   2.495997  3.678571  3.948661  194580400
# 3   AAPL  3.790179  3.392857   2.279998  3.392857  3.821429  191993200
# 4   AAPL  3.446429  3.553571   2.387998  3.410714  3.607143  115183600
#
#          date      sector  year  month  day
# 0  2000-01-03  TECHNOLOGY  2000      1    3
# 1  2000-01-04  TECHNOLOGY  2000      1    4
# 2  2000-01-05  TECHNOLOGY  2000      1    5
# 3  2000-01-06  TECHNOLOGY  2000      1    6
# 4  2000-01-07  TECHNOLOGY  2000      1    7

# %%
df_sarimax["spread"] = df_sarimax["open"] - df_sarimax["close"]
df_sarimax.head()
# Out:
#   ticker      open     close  adj_close       low      high     volume  \
# 0   AAPL  3.745536  3.997768   2.686497  3.631696  4.017857  133949200
# 1   AAPL  3.866071  3.660714   2.459998  3.613839  3.950893  128094400
# 2   AAPL  3.705357  3.714286   2.495997  3.678571  3.948661  194580400
# 3   AAPL  3.790179  3.392857   2.279998  3.392857  3.821429  191993200
# 4   AAPL  3.446429  3.553571   2.387998  3.410714  3.607143  115183600
#
#          date      sector  year  month  day    spread
# 0  2000-01-03  TECHNOLOGY  2000      1    3 -0.252232
# 1  2000-01-04  TECHNOLOGY  2000      1    4  0.205357
# 2  2000-01-05  TECHNOLOGY  2000      1    5 -0.008929
# 3  2000-01-06  TECHNOLOGY  2000      1    6  0.397321
# 4  2000-01-07  TECHNOLOGY  2000      1    7 -0.107143

# %%
plt.figure(figsize=(20,5))
plt.plot(df_sarimax.adj_close);

# %%
plt.figure(figsize=(20,5))
plt.plot(df_sarimax.spread);

# %%
#plt.plot(df_sarimax.adj_close);
#Ask Sandra later for the adj_close

# %%
df_groupby = df_sarimax.groupby(["ticker"])["spread"].median()
df_groupby
# Out:
# ticker
# A      -0.021460
# AAL     0.020000
# AAP     0.000000
# AAPL   -0.003571
# ABBV   -0.079998
#           ...
# YUM    -0.014378
# ZBH    -0.050003
# ZBRA   -0.021112
# ZION   -0.010000
# ZTS     0.010000
# Name: spread, Length: 481, dtype: float64

# %%
plt.figure(figsize=(25,10))
plt.plot(df_groupby);

# %%
#df_sarimax = df_sarimax[]
#pd.to_datetime(df["date"], format='%Y%m%d', errors='ignore')

# %%
df_sarimax["date"] = pd.to_datetime(df_sarimax["date"], infer_datetime_format=True)
df_sarimax.head()
# Out:
#   ticker      open     close  adj_close       low      high     volume  \
# 0   AAPL  3.745536  3.997768   2.686497  3.631696  4.017857  133949200
# 1   AAPL  3.866071  3.660714   2.459998  3.613839  3.950893  128094400
# 2   AAPL  3.705357  3.714286   2.495997  3.678571  3.948661  194580400
# 3   AAPL  3.790179  3.392857   2.279998  3.392857  3.821429  191993200
# 4   AAPL  3.446429  3.553571   2.387998  3.410714  3.607143  115183600
#
#         date      sector  year  month  day    spread
# 0 2000-01-03  TECHNOLOGY  2000      1    3 -0.252232
# 1 2000-01-04  TECHNOLOGY  2000      1    4  0.205357
# 2 2000-01-05  TECHNOLOGY  2000      1    5 -0.008929
# 3 2000-01-06  TECHNOLOGY  2000      1    6  0.397321
# 4 2000-01-07  TECHNOLOGY  2000      1    7 -0.107143

# %%
df_sarimax["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_sarimax.reset_index()
df_sarimax = df_sarimax.set_index(df_sarimax["date"])
df_sarimax = df_sarimax.drop("date", axis=1)

# %%
df_sarimax.head()
# Out:
#            ticker      open     close  adj_close       low      high  \
# date
# 2000-01-03   AAPL  3.745536  3.997768   2.686497  3.631696  4.017857
# 2000-01-04   AAPL  3.866071  3.660714   2.459998  3.613839  3.950893
# 2000-01-05   AAPL  3.705357  3.714286   2.495997  3.678571  3.948661
# 2000-01-06   AAPL  3.790179  3.392857   2.279998  3.392857  3.821429
# 2000-01-07   AAPL  3.446429  3.553571   2.387998  3.410714  3.607143
#
#                volume      sector  year  month  day    spread
# date
# 2000-01-03  133949200  TECHNOLOGY  2000      1    3 -0.252232
# 2000-01-04  128094400  TECHNOLOGY  2000      1    4  0.205357
# 2000-01-05  194580400  TECHNOLOGY  2000      1    5 -0.008929
# 2000-01-06  191993200  TECHNOLOGY  2000      1    6  0.397321
# 2000-01-07  115183600  TECHNOLOGY  2000      1    7 -0.107143

# %% [markdown]
# ### Decomposition

# %%
df_sarimax = df_sarimax[(df_sarimax.index)>"1999-12-31"]
df_sarimax.head()
# Out:
#            ticker      open     close  adj_close       low      high  \
# date
# 2000-01-03   AAPL  3.745536  3.997768   2.686497  3.631696  4.017857
# 2000-01-04   AAPL  3.866071  3.660714   2.459998  3.613839  3.950893
# 2000-01-05   AAPL  3.705357  3.714286   2.495997  3.678571  3.948661
# 2000-01-06   AAPL  3.790179  3.392857   2.279998  3.392857  3.821429
# 2000-01-07   AAPL  3.446429  3.553571   2.387998  3.410714  3.607143
#
#                volume      sector  year  month  day    spread
# date
# 2000-01-03  133949200  TECHNOLOGY  2000      1    3 -0.252232
# 2000-01-04  128094400  TECHNOLOGY  2000      1    4  0.205357
# 2000-01-05  194580400  TECHNOLOGY  2000      1    5 -0.008929
# 2000-01-06  191993200  TECHNOLOGY  2000      1    6  0.397321
# 2000-01-07  115183600  TECHNOLOGY  2000      1    7 -0.107143

# %%
df_telekom = df_sarimax[df_sarimax["ticker"]== "T"]
df_telekom.head()
# Out:
#            ticker     open    close  adj_close      low   high   volume  \
# date
# 2000-01-03      T  48.5625  47.0000  19.225044  46.6250  49.00  5791900
# 2000-01-04      T  47.0625  44.2500  18.100174  43.5000  47.75  7173600
# 2000-01-05      T  45.0000  44.9375  18.381397  44.4375  45.25  9090000
# 2000-01-06      T  44.5625  43.7500  17.993273  43.1250  45.00  7153600
# 2000-01-07      T  44.5625  44.1250  18.147497  43.3750  44.75  5885600
#
#                       sector  year  month  day  spread
# date
# 2000-01-03  PUBLIC UTILITIES  2000      1    3  1.5625
# 2000-01-04  PUBLIC UTILITIES  2000      1    4  2.8125
# 2000-01-05  PUBLIC UTILITIES  2000      1    5  0.0625
# 2000-01-06  PUBLIC UTILITIES  2000      1    6  0.8125
# 2000-01-07  PUBLIC UTILITIES  2000      1    7  0.4375

# %%
# additive Decomposition (y = Trend * Seasonal * Residuals)
result_add_T = seasonal_decompose(df_telekom['adj_close'], model='additive', period=365)
result_add_T.plot();

# %%
#Multiplicative Decomposition
result_mult_T = seasonal_decompose(df_telekom['adj_close'], model='multiplicative', period=365)
result_mult_T.plot();

# %% [markdown]
# ### Check for stationality

# %%
# Plot the residuals with "result_add.resid" to decide
#f, (ax1, ax2) = plt.subplots(1,2, figsize=(13,3))
#ax1.plot(result_add.resid); ax1.set_title("Additive model residuals")
#ax2.plot(result_mul.resid); ax2.set_title("Multiplicative model residuals");

# %%
result_mult_T.__dict__
# Out:
# {'_seasonal': date
#  2000-01-03    0.985170
#  2000-01-04    0.983190
#  2000-01-05    0.977054
#  2000-01-06    0.978178
#  2000-01-07    0.982755
#                  ...
#  2018-08-20    0.991055
#  2018-08-21    0.994408
#  2018-08-22    0.998287
#  2018-08-23    1.000208
#  2018-08-24    0.996673
#  Name: seasonal, Length: 4692, dtype: float64,
#  '_trend': date
#  2000-01-03   NaN
#  2000-01-04   NaN
#  2000-01-05   NaN
#  2000-01-06   NaN
#  2000-01-07   NaN
#                ..
#  2018-08-20   NaN
#  2018-08-21   NaN
#  2018-08-22   NaN
#  2018-08-23   NaN
#  2018-08-24   NaN
#  Name: trend, Length: 4692, dtype: float64,
#  '_weights': date
#  2000-01-03    1.0
#  2000-01-04    1.0
#  2000-01-05    1.0
#  2000-01-06    1.0
#  2000-01-07    1.0
#               ...
#  2018-08-20    1.0
#  2018-08-21    1.0
#  2018-08-22    1.0
#  2018-08-23    1.0
#  2018-08-24    1.0
#  Name: weights, Length: 4692, dtype: float64,
#  '_resid': date
#  2000-01-03   NaN
#  2000-01-04   NaN
#  2000-01-05   NaN
#  2000-01-06   NaN
#  2000-01-07   NaN
#                ..
#  2018-08-20   NaN
#  2018-08-21   NaN
#  2018-08-22   NaN
#  2018-08-23   NaN
#  2018-08-24   NaN
#  Name: resid, Length: 4692, dtype: float64,
#  '_observed': date
#  2000-01-03    19.225044
#  2000-01-04    18.100174
#  2000-01-05    18.381397
#  2000-01-06    17.993273
#  2000-01-07    18.147497
#                  ...
#  2018-08-20    33.110001
#  2018-08-21    33.400002
#  2018-08-22    32.680000
#  2018-08-23    32.490002
#  2018-08-24    32.639999
#  Name: adj_close, Length: 4692, dtype: float64}

# %%
result_mult_T.resid
# Out:
# date
# 2000-01-03   NaN
# 2000-01-04   NaN
# 2000-01-05   NaN
# 2000-01-06   NaN
# 2000-01-07   NaN
#               ..
# 2018-08-20   NaN
# 2018-08-21   NaN
# 2018-08-22   NaN
# 2018-08-23   NaN
# 2018-08-24   NaN
# Name: resid, Length: 4692, dtype: float64

# %%
result_observed=result_mult_T.observed.dropna()

# %%
x =adfuller(result_observed)[1]  # p-value

# %%
y = result_observed.diff(12).dropna()
fig, axes = plt.subplots(1,2,figsize=(12,4))
axes[0].plot(y)
plot_acf(y, ax=axes[1])
print('p-value: ', x)

#plot_acf(y.diff(1).dropna());
#print('p-value: ', adfuller(y_diff_12.diff(1).dropna())[1])
# Out:
# p-value:  0.8011297307453698

# %%
plot_acf(y.diff(1).dropna());
print('p-value: ', adfuller(y.diff(1).dropna())[1])
# Out:
# p-value:  0.0

# %%
print("p-value: ", adfuller(df_telekom["adj_close"])[1])
# Out:
# p-value:  0.8011297307453698

# %% [markdown]
# ### Autocorrelation

# %%
y = df_telekom.adj_close
#plot_acf(df_telekom["adj_close"], lags=50)
plot_acf(y);

# %%
plot_pacf(df_telekom.adj_close, lags=50, c='r')
#plt.show()

# %%
#Plot telekom stock
plt.plot(df_telekom.adj_close);

# %% [markdown]
# ## Building the SARIMA model

# %%
#I make the log to run the SARIMA MODel
df["log_adjust"] = df["adjust"].map(lambda x: log(x))

# %%
#convert again to exponential form to make the predictions
#df[‘log_adj_close’] = df[‘adj_close’].map(lambda x: log(x))
#exp(x)

# %%
model = pm.auto_arima(df_telekom["adj_close"],
                      m=365, # frequency of series. Important to choose manually
                      seasonal=False,
                      stepwise=True,  # only check most interesting combination. False will take way longer.
                      start_p=0, max_p=2,
                      start_d=0, max_d=1,
                      start_q=0, max_q=2,
                      start_P=0, max_P=2,
                      start_D=0, max_D=2,
                      start_Q=0, max_Q=2,
                      njobs=-1, trace=True, error_action="ignore",  suppress_warnings=True)
print(model.summary())
# Out:
# /Users/tara-sophiatumbraegel/.pyenv/versions/3.8.6/envs/stock_prices_predictions/lib/python3.8/site-packages/pmdarima/arima/_validation.py:62: UserWarning: m (365) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2305.187, Time=0.92 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2306.991, Time=0.47 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2306.962, Time=0.87 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2303.588, Time=0.38 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2296.826, Time=4.71 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2290.633, Time=3.25 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2289.113, Time=0.99 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=2287.580, Time=0.40 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2305.398, Time=0.35 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2289.118, Time=1.18 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2295.410, Time=1.13 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0]
# Total fit time: 14.658 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4692
# Model:               SARIMAX(2, 1, 0)   Log Likelihood               -1140.790
# Date:                Wed, 02 Jun 2021   AIC                           2287.580
# Time:                        12:13:26   BIC                           2306.940
# Sample:                             0   HQIC                          2294.387
#                                - 4692
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0067      0.010     -0.652      0.514      -0.027       0.014
# ar.L2         -0.0650      0.011     -5.834      0.000      -0.087      -0.043
# sigma2         0.0952      0.001     97.742      0.000       0.093       0.097
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7709.49
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                            -0.32
# Prob(H) (two-sided):                  0.73   Kurtosis:                         9.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
